# %%
import pandas as pd
import numpy as np

# %%
shoe_data = pd.read_csv('data.csv')

# %%
shoe_data.head()
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0         1       53      746           224            2           cash
# 1         2       92      925            90            1           cash
# 2         3       44      861           144            1           cash
# 3         4       18      935           156            1    credit_card
# 4         5       18      883           156            1    credit_card
#
#             created_at
# 0  2017-03-13 12:36:56
# 1  2017-03-03 17:38:52
# 2   2017-03-14 4:23:56
# 3  2017-03-26 12:43:37
# 4   2017-03-01 4:35:11

# %% [markdown]
# ## Question 1

# %% [markdown]
# #### a)
#
# As seen directly below, the value of 3145.13 seems to have been calculated using the definition of a sample mean:
#
# $\bar{y} = (\sum \limits_{i=1}^{n} y_{i}) / n$

# %%
aov_sample_mean = shoe_data['order_amount'].mean()

# %%
print(aov_sample_mean)
# Out:
# 3145.128

# %% [markdown]
# The sample mean is sensitive to outliers which may be present in the data. These outliers can misrepresent the data when using something like the sample mean to represent your average order value.

# %% [markdown]
# ### Some Exploration...

# %%
shoe_data['order_amount'].describe()
# Out:
# count      5000.000000
# mean       3145.128000
# std       41282.539349
# min          90.000000
# 25%         163.000000
# 50%         284.000000
# 75%         390.000000
# max      704000.000000
# Name: order_amount, dtype: float64

# %%
shoe_data['user_id'].value_counts() # generate counts of users ordering
# Out:
# 718    28
# 868    27
# 791    26
# 847    26
# 787    25
#        ..
# 902     9
# 812     9
# 955     9
# 717     7
# 750     7
# Name: user_id, Length: 301, dtype: int64

# %%
shoe_data.boxplot(column=['order_amount'])
# Out:
# <AxesSubplot:>

# %%
shoe_data['order_amount'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### More thoughts...

# %% [markdown]
# These plots are concerning...the outliers are so significant that the histogram is being heavily misrepresented. Moreover, the boxplot is not very informative due to the outliers which causes it to become a single straight line.

# %% [markdown]
# Moreover, there is interesting activity occuring in the data upon further inspection. We can see that certain users are making many purchases in comparison to the rest.

# %% [markdown]
# #### b)

# %% [markdown]
# We could do some outlier analysis in order to strategically come up with a new metric or we can do something simple like take the median which is more resilient to outliers than the sample mean.

# %% [markdown]
# #### c)
#
# The median value is $284

# %%
print(shoe_data['order_amount'].median())
# Out:
# 284.0

# %% [markdown]
# ## Question 2

# %% [markdown]
# #### a)

# %% [markdown]
# ![Screen%20Shot%202021-09-20%20at%209.05.49%20PM.png](attachment:Screen%20Shot%202021-09-20%20at%209.05.49%20PM.png)

# %% [markdown]
# #### b)

# %% [markdown]
# ![Screen%20Shot%202021-09-20%20at%2010.52.59%20PM.png](attachment:Screen%20Shot%202021-09-20%20at%2010.52.59%20PM.png)

# %% [markdown]
# #### c)
#
# I am typing out my query here because it did not fit on the screen from the sql Tryit Editor Window.

# %%
SELECT TOP 1 ProductName, SUM(Quantity)
FROM ((Products
LEFT JOIN OrderDetails
ON Products.ProductID = OrderDetails.ProductID)
LEFT JOIN Orders
ON OrderDetails.OrderID = Orders.OrderID)
LEFT JOIN Customers
ON Orders.CustomerID = Customers.CustomerID
WHERE Country = 'Germany'
Group By ProductName
ORDER BY SUM(Quantity) DESC

# %% [markdown]
# ![Screen%20Shot%202021-09-21%20at%201.42.30%20PM.png](attachment:Screen%20Shot%202021-09-21%20at%201.42.30%20PM.png)
